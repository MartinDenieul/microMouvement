# %%
import pandas as pd
import micro
import os
import numpy as np
import numpy.fft as fft
import matplotlib.pyplot as plt
import matplotlib
import write
import math
os.chdir('data_passation')

# %%
filename = 'tsa_1/tsa1_ecriture_Lune.csv'
tsa1 = pd.read_csv(filename)
tsa1XY = write.analyse(tsa1)
# Out:
# C:\Users\Martin\Desktop\write.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pressure'][df['pressure'] <0] += 1	#Recale les 'pressure'#
# C:\Users\Martin\Desktop\write.py:56: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['code'][:listeMot[0]] = 1
# C:\Users\Martin\Desktop\write.py:59: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['code'][listeMot[i-1]:listeMot[i]]=c
# ...

# %%
filename = 'tsa_4/tsa4_ecriture_Lune.csv'
tsa4 = pd.read_csv(filename)
tsa4XY = write.analyse(tsa4)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'tsa_5/tsa5_ecriture_Lune.csv'
tsa5 = pd.read_csv(filename)
tsa5XY = write.analyse(tsa5)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'tsa_6/tsa6_ecriture_Lune.csv'
tsa6 = pd.read_csv(filename)
tsa6XY = write.analyse(tsa6)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'tsa_8/tsa8_ecriture_Lune.csv'
tsa8 = pd.read_csv(filename)
tsa8XY = write.analyse(tsa8)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'ctrl_1/ctrl1_ecriture_Lune.csv'
ctrl1 = pd.read_csv(filename)
ctrl1XY = write.analyse(ctrl1)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'ctrl_2/ctrl2_ecriture_Lune.csv'
ctrl2 = pd.read_csv(filename)
ctrl2XY = write.analyse(ctrl2)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'ctrl_3/ctrl3_ecriture_Lune.csv'
ctrl3 = pd.read_csv(filename)
ctrl3XY = write.analyse(ctrl3)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'ctrl_4/ctrl4_ecriture_Lune.csv'
ctrl4 = pd.read_csv(filename)
ctrl4XY = write.analyse(ctrl4)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'ctrl_5/ctrl5_ecriture_Lune.csv'
ctrl5 = pd.read_csv(filename)
ctrl5XY = write.analyse(ctrl5)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'ctrl_6/ctrl6_ecriture_Lune.csv'
ctrl6 = pd.read_csv(filename)
ctrl6XY = write.analyse(ctrl6)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'ctrl_8/ctrl8_ecriture_Lune.csv'
ctrl8 = pd.read_csv(filename)
ctrl8XY = write.analyse(ctrl8)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'ctrl_9/ctrl9_ecriture_Lune.csv'
ctrl9 = pd.read_csv(filename)
ctrl9XY = write.analyse(ctrl9)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'ctrl_10/ctrl10_ecriture_Lune.csv'
ctrl10 = pd.read_csv(filename)
ctrl10XY = write.analyse(ctrl10)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'ctrl_11/ctrl11_ecriture_Lune.csv'
ctrl11 = pd.read_csv(filename)
ctrl11XY = write.analyse(ctrl11)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'ctrl_12/ctrl12_ecriture_Lune.csv'
ctrl12 = pd.read_csv(filename)
ctrl12XY = write.analyse(ctrl12)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'dpx_1/dpx1_ecriture_Lune.csv'
dpx1 = pd.read_csv(filename)
dpx1XY = write.analyse(dpx1)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'dpx_2/dpx2_ecriture_Lune.csv'
dpx2 = pd.read_csv(filename)
dpx2XY = write.analyse(dpx2)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'dpx_3/dpx3_ecriture_Lune.csv'
dpx3 = pd.read_csv(filename)
dpx3XY = write.analyse(dpx3)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'dpx_4/dpx4_ecriture_Lune.csv'
dpx4 = pd.read_csv(filename)
dpx4XY = write.analyse(dpx4)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'dpx_5/dpx5_ecriture_Lune.csv'
dpx5 = pd.read_csv(filename)
dpx5XY = write.analyse(dpx5)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
filename = 'dpx_6/dpx6_ecriture_Lune.csv'
dpx6 = pd.read_csv(filename)
dpx6XY = write.analyse(dpx6)
# Out:
#                                                   ANALYSE ECRITURE
#                                                VOICI LES DATAS ANALYSÉES

# %%
f=np.arange(0,64,1)
plt.figure(figsize=(16,10))
gtsa1 = plt.plot(f, tsa1XY[64:], color='red')
gtsa4 = plt.plot(f, tsa4XY[64:], color='red')
gtsa5 = plt.plot(f, tsa5XY[64:], color='red')
gtsa6 = plt.plot(f, tsa6XY[64:], color='red')
gtsa8 = plt.plot(f, tsa8XY[64:], color='red')

gctrl1 = plt.plot(f, ctrl1XY[64:], color='blue')
gctrl2 = plt.plot(f, ctrl2XY[64:], color='blue')
gctrl3 = plt.plot(f, ctrl3XY[64:], color='blue')
gctrl4 = plt.plot(f, ctrl4XY[64:], color='blue')
gctrl5 = plt.plot(f, ctrl5XY[64:], color='blue')
gctrl6 = plt.plot(f, ctrl6XY[64:], color='blue')
gctrl8 = plt.plot(f, ctrl8XY[64:], color='blue')
gctrl9 = plt.plot(f, ctrl9XY[64:], color='blue')
gctrl10 = plt.plot(f, ctrl10XY[64:], color='blue')
gctrl11 = plt.plot(f, ctrl11XY[64:], color='blue')
gctrl12 = plt.plot(f, ctrl12XY[64:], color='blue')

gdpx1 = plt.plot(f, dpx1XY[64:], color='green')
gdpx2 = plt.plot(f, dpx2XY[64:], color='green')
gdpx3 = plt.plot(f, dpx3XY[64:], color='green')
gdpx4 = plt.plot(f, dpx4XY[64:], color='green')
gdpx5 = plt.plot(f, dpx5XY[64:], color='green')
gdpx6 = plt.plot(f, dpx6XY[64:], color='green')

# %%
#########################################     MOYENNE        ################################
#############################################################################################

listeTsaXY=[tsa1XY, tsa4XY, tsa5XY, tsa6XY, tsa8XY]
listeCtrlXY=[ctrl1XY, ctrl2XY, ctrl3XY, ctrl4XY, ctrl5XY, ctrl6XY, ctrl8XY, ctrl9XY, ctrl10XY, ctrl11XY, ctrl12XY]
listeDpxXY=[dpx1XY, dpx2XY, dpx3XY, dpx4XY, dpx5XY, dpx6XY]

meanTsaXY = np.mean(listeTsaXY, axis=0)
meanCtrlXY = np.mean(listeCtrlXY, axis=0)
meanDpxXY = np.mean(listeDpxXY, axis=0)

varTsaXY = np.var(listeTsaXY, axis=0)
varCtrlXY = np.var(listeCtrlXY, axis=0)
varDpxXY= np.var(listeDpxXY, axis=0)

varTsaMoins = meanTsaXY - varTsaXY
varTsaPlus = meanTsaXY + varTsaXY
varCtrlMoins = meanCtrlXY - varCtrlXY
varCtrlPlus = meanCtrlXY + varTsaXY
varDpxMoins = meanDpxXY - varDpxXY
varDpxPlus = meanDpxXY + varDpxXY

# %%
f=np.arange(0,64,1)
plt.figure(figsize=(17,10))
plt.plot(f,meanTsaXY[64:],color='red')
plt.plot(f,meanCtrlXY[64:], color='blue')
plt.plot(f,meanDpxXY[64:], color='green')

# %%
tsa1XY
# Out:
# array([-3.96610581, -3.95048795, -3.94189903, -3.94719299, -3.93008267,
#        -3.95617142, -3.9183065 , -3.93979695, -3.98666972, -3.93656515,
#        -3.92796021, -3.9086205 , -3.95115341, -3.89894215, -3.87612181,
#        -3.89861068, -3.86272116, -3.86923069, -3.86936795, -3.83476304,
#        -3.81397633, -3.83218014, -3.85383767, -3.78850614, -3.78087227,
#        -3.75108376, -3.71963971, -3.725982  , -3.71091647, -3.67608223,
#        -3.63879635, -3.64127488, -3.58361149, -3.58407959, -3.57209504,
#        -3.53744106, -3.52863087, -3.47657629, -3.43804425, -3.41460561,
#        -3.38897225, -3.33700192, -3.29428727, -3.25062455, -3.23882497,
#        -3.15537007, -3.12894005, -3.05925391, -2.9852058 , -2.93660673,
#        -2.882499  , -2.8047302 , -2.70973699, -2.64503404, -2.54742585,
#        -2.4441469 , -2.33534734, -2.18961673, -2.04311306, -1.86406887,
#        -1.6119979 , -1.28996308, -0.77349772, -0.22744788,  5.52584423,
# ...
